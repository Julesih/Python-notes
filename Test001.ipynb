# %% [markdown]
# <a href="https://colab.research.google.com/github/Julesih/Python-notes/blob/master/Test001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from numpy import *

# %%
x=linspace(0, 2*pi, 100)
fig, ax = plt.subplots(1)
ax.plot(x, sin(x))

# %%
fig, ax = plt.subplots(1)
ax.plot(x, cos(x))
